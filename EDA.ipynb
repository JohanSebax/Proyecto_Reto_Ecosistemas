# %%
import pandas as pd
import numpy as np
import datetime as dt
import sqlite3

# %%
try:

	# Connect to DB and create a cursor
	sqliteConnection = sqlite3.connect("database.sqlite")
	cursor = sqliteConnection.cursor()
	print('DB Init')

	# Write a query and execute it with cursor
	query = 'select sqlite_version();'
	cursor.execute(query)

	# Fetch and output result
	result = cursor.fetchall()
	print('SQLite Version is {}'.format(result))

	# Close the cursor
	cursor.close()

# Handle errors
except sqlite3.Error as error:
	print('Error occurred - ', error)

# Close DB Connection irrespective of success
# or failure
finally:

	if sqliteConnection:
		sqliteConnection.close()
		print('SQLite Connection closed')
# Out:
# DB Init
# SQLite Version is [('3.45.3',)]
# SQLite Connection closed

# %%
sqliteConnection = sqlite3.connect("database.sqlite")

# Query to extract apicall table
query_apicall = "SELECT * FROM apicall;"
apicall = pd.read_sql_query(query_apicall, sqliteConnection)

# Query to extract commerce table
query_commerce = "SELECT * FROM commerce;"
commerce = pd.read_sql_query(query_commerce, sqliteConnection)

sqliteConnection.close()

# %% [markdown]
# # Analisis exploratorio de datos (EDA)

# %%
apicall.head()
# Out:
#          date_api_call          commerce_id  ask_status  is_related
# 0  2024-10-21 18:31:16  GdEQ-MGb7-LXHa-y6cd  Successful         1.0
# 1  2024-10-13 17:12:08  GdEQ-MGb7-LXHa-y6cd  Successful         1.0
# 2  2024-12-23 01:02:06  Rh2k-J1o7-zndZ-cOo8  Successful         1.0
# 3  2024-07-11 07:24:35  GdEQ-MGb7-LXHa-y6cd  Successful         1.0
# 4  2024-06-28 11:43:52  Rh2k-J1o7-zndZ-cOo8  Successful         1.0

# %%
commerce
# Out:
#            commerce_id  commerce_nit           commerce_name commerce_status  \
# 0  KaSn-4LHo-m6vC-I4PU     445470636      Innovexa Solutions        Inactive
# 1  Vj9W-c4Pm-ja0X-fC1C     452680670     NexaTech Industries          Active
# 2  Rh2k-J1o7-zndZ-cOo8     198818316        QuantumLeap Inc.          Active
# 3  3VYd-4lzT-mTC3-DQN5      28960112            Zenith Corp.          Active
# 4  GdEQ-MGb7-LXHa-y6cd     919341007  FusionWave Enterprises          Active
#
#                           commerce_email
# 0      innovexasolutions@microfitsof.com
# 1         nexatechindustries@gemaily.net
# 2            quantumleapinc.@gemaily.net
# 3                zenithcorp.@gemaily.net
# 4  fusionwaveenterprises@microfitsof.com

# %%
# Revisamos tipo de datos con info()

apicall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   date_api_call  1500000 non-null  object
#  1   commerce_id    1500000 non-null  object
#  2   ask_status     1500000 non-null  object
#  3   is_related     1200495 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 45.8+ MB

# %%
commerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   commerce_id      5 non-null      object
#  1   commerce_nit     5 non-null      int64
#  2   commerce_name    5 non-null      object
#  3   commerce_status  5 non-null      object
#  4   commerce_email   5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 332.0+ bytes

# %%
# Pasamos la columna con fechas a datetime

apicall["date_api_call"] = apicall["date_api_call"].map(lambda x: dt.datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))
apicall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   date_api_call  1500000 non-null  datetime64[ns]
#  1   commerce_id    1500000 non-null  object
#  2   ask_status     1500000 non-null  object
#  3   is_related     1200495 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 45.8+ MB

# %%
# Usamos el metodo merge() para unir ambas tablas

apicall_commerce = apicall.merge(commerce, on="commerce_id")
apicall_commerce.head()
# Out:
#         date_api_call          commerce_id  ask_status  is_related  \
# 0 2024-10-21 18:31:16  GdEQ-MGb7-LXHa-y6cd  Successful         1.0
# 1 2024-10-13 17:12:08  GdEQ-MGb7-LXHa-y6cd  Successful         1.0
# 2 2024-12-23 01:02:06  Rh2k-J1o7-zndZ-cOo8  Successful         1.0
# 3 2024-07-11 07:24:35  GdEQ-MGb7-LXHa-y6cd  Successful         1.0
# 4 2024-06-28 11:43:52  Rh2k-J1o7-zndZ-cOo8  Successful         1.0
#
#    commerce_nit           commerce_name commerce_status  \
# 0     919341007  FusionWave Enterprises          Active
# 1     919341007  FusionWave Enterprises          Active
# 2     198818316        QuantumLeap Inc.          Active
# 3     919341007  FusionWave Enterprises          Active
# 4     198818316        QuantumLeap Inc.          Active
#
#                           commerce_email
# 0  fusionwaveenterprises@microfitsof.com
# 1  fusionwaveenterprises@microfitsof.com
# 2            quantumleapinc.@gemaily.net
# 3  fusionwaveenterprises@microfitsof.com
# 4            quantumleapinc.@gemaily.net

# %%
apicall_commerce.sample(20)
# Out:
#               date_api_call          commerce_id    ask_status  is_related  \
# 335555  2024-05-12 21:41:07  KaSn-4LHo-m6vC-I4PU    Successful         0.0
# 826895  2024-05-16 13:23:32  GdEQ-MGb7-LXHa-y6cd    Successful         1.0
# 16291   2024-08-01 03:53:00  KaSn-4LHo-m6vC-I4PU    Successful         0.0
# 461472  2024-03-29 16:29:47  Vj9W-c4Pm-ja0X-fC1C    Successful         1.0
# 1347786 2024-12-23 14:07:32  GdEQ-MGb7-LXHa-y6cd  Unsuccessful         NaN
# 1459545 2024-11-05 02:58:01  Rh2k-J1o7-zndZ-cOo8    Successful         1.0
# 1375777 2024-10-26 00:49:56  GdEQ-MGb7-LXHa-y6cd    Successful         1.0
# 88254   2024-03-02 07:04:10  3VYd-4lzT-mTC3-DQN5    Successful         1.0
# 1355838 2024-02-14 21:03:16  Rh2k-J1o7-zndZ-cOo8    Successful         1.0
# 1328816 2024-04-06 22:33:39  Rh2k-J1o7-zndZ-cOo8    Successful         1.0
# 994706  2024-02-16 19:43:40  KaSn-4LHo-m6vC-I4PU    Successful         1.0
# 192504  2024-02-20 09:11:32  KaSn-4LHo-m6vC-I4PU    Successful         1.0
# 599333  2024-06-02 17:45:03  3VYd-4lzT-mTC3-DQN5    Successful         0.0
# 116837  2024-09-30 09:02:03  KaSn-4LHo-m6vC-I4PU    Successful         1.0
# 852137  2024-08-15 05:06:58  KaSn-4LHo-m6vC-I4PU    Successful         1.0
# 1188723 2024-08-03 02:40:13  GdEQ-MGb7-LXHa-y6cd    Successful         0.0
# 124073  2024-03-17 06:00:39  Vj9W-c4Pm-ja0X-fC1C    Successful         1.0
# 103227  2024-01-23 17:07:36  Rh2k-J1o7-zndZ-cOo8    Successful         1.0
# 711836  2024-11-28 07:14:04  Rh2k-J1o7-zndZ-cOo8  Unsuccessful         NaN
# 1058425 2024-03-08 23:56:26  Vj9W-c4Pm-ja0X-fC1C  Unsuccessful         NaN
#
#          commerce_nit           commerce_name commerce_status  \
# 335555      445470636      Innovexa Solutions        Inactive
# 826895      919341007  FusionWave Enterprises          Active
# 16291       445470636      Innovexa Solutions        Inactive
# 461472      452680670     NexaTech Industries          Active
# 1347786     919341007  FusionWave Enterprises          Active
# 1459545     198818316        QuantumLeap Inc.          Active
# 1375777     919341007  FusionWave Enterprises          Active
# 88254        28960112            Zenith Corp.          Active
# 1355838     198818316        QuantumLeap Inc.          Active
# 1328816     198818316        QuantumLeap Inc.          Active
# 994706      445470636      Innovexa Solutions        Inactive
# 192504      445470636      Innovexa Solutions        Inactive
# 599333       28960112            Zenith Corp.          Active
# 116837      445470636      Innovexa Solutions        Inactive
# 852137      445470636      Innovexa Solutions        Inactive
# 1188723     919341007  FusionWave Enterprises          Active
# 124073      452680670     NexaTech Industries          Active
# 103227      198818316        QuantumLeap Inc.          Active
# 711836      198818316        QuantumLeap Inc.          Active
# 1058425     452680670     NexaTech Industries          Active
#
#                                 commerce_email
# 335555       innovexasolutions@microfitsof.com
# 826895   fusionwaveenterprises@microfitsof.com
# 16291        innovexasolutions@microfitsof.com
# 461472          nexatechindustries@gemaily.net
# 1347786  fusionwaveenterprises@microfitsof.com
# 1459545            quantumleapinc.@gemaily.net
# 1375777  fusionwaveenterprises@microfitsof.com
# 88254                  zenithcorp.@gemaily.net
# 1355838            quantumleapinc.@gemaily.net
# 1328816            quantumleapinc.@gemaily.net
# 994706       innovexasolutions@microfitsof.com
# 192504       innovexasolutions@microfitsof.com
# 599333                 zenithcorp.@gemaily.net
# 116837       innovexasolutions@microfitsof.com
# 852137       innovexasolutions@microfitsof.com
# 1188723  fusionwaveenterprises@microfitsof.com
# 124073          nexatechindustries@gemaily.net
# 103227             quantumleapinc.@gemaily.net
# 711836             quantumleapinc.@gemaily.net
# 1058425         nexatechindustries@gemaily.net

# %%
apicall_commerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   date_api_call    1500000 non-null  datetime64[ns]
#  1   commerce_id      1500000 non-null  object
#  2   ask_status       1500000 non-null  object
#  3   is_related       1200495 non-null  float64
#  4   commerce_nit     1500000 non-null  int64
#  5   commerce_name    1500000 non-null  object
#  6   commerce_status  1500000 non-null  object
#  7   commerce_email   1500000 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 91.6+ MB

# %%
# Usamos describe() en las columnas con fechas y numericas

print(apicall_commerce["date_api_call"].describe())
# Out:
# count                          1500000
# mean     2024-07-02 00:33:23.949236224
# min                2024-01-01 00:00:15
# 25%         2024-04-01 16:45:41.500000
# 50%         2024-07-01 23:32:30.500000
# 75%         2024-10-01 10:41:27.500000
# max                2024-12-31 23:59:39
# Name: date_api_call, dtype: object

# %%
print(apicall_commerce["commerce_status"].describe())
# Out:
# count     1500000
# unique          2
# top        Active
# freq      1199900
# Name: commerce_status, dtype: object

# %%
print(apicall_commerce["is_related"].value_counts(dropna=False))
# Out:
# is_related
# 1.0    800928
# 0.0    399567
# NaN    299505
# Name: count, dtype: int64

# %%
apicall_commerce[apicall_commerce["is_related"].isna()].sample(20)
# Out:
#               date_api_call          commerce_id    ask_status  is_related  \
# 1488207 2024-07-20 10:26:12  Rh2k-J1o7-zndZ-cOo8  Unsuccessful         NaN
# 1169407 2024-09-24 19:57:30  Rh2k-J1o7-zndZ-cOo8  Unsuccessful         NaN
# 1333702 2024-12-23 18:10:59  Rh2k-J1o7-zndZ-cOo8  Unsuccessful         NaN
# 839492  2024-04-18 06:12:36  KaSn-4LHo-m6vC-I4PU  Unsuccessful         NaN
# 295944  2024-03-17 09:05:16  GdEQ-MGb7-LXHa-y6cd  Unsuccessful         NaN
# 888732  2024-08-16 22:45:37  3VYd-4lzT-mTC3-DQN5  Unsuccessful         NaN
# 157830  2024-08-30 17:19:30  3VYd-4lzT-mTC3-DQN5  Unsuccessful         NaN
# 636435  2024-11-07 05:59:12  3VYd-4lzT-mTC3-DQN5  Unsuccessful         NaN
# 202690  2024-06-26 00:49:34  3VYd-4lzT-mTC3-DQN5  Unsuccessful         NaN
# 354401  2024-11-03 03:14:45  GdEQ-MGb7-LXHa-y6cd  Unsuccessful         NaN
# 994423  2024-06-13 10:47:00  Vj9W-c4Pm-ja0X-fC1C  Unsuccessful         NaN
# 39658   2024-08-22 06:56:09  GdEQ-MGb7-LXHa-y6cd  Unsuccessful         NaN
# 972606  2024-01-05 05:04:51  GdEQ-MGb7-LXHa-y6cd  Unsuccessful         NaN
# 1394925 2024-04-02 19:29:44  KaSn-4LHo-m6vC-I4PU  Unsuccessful         NaN
# 363305  2024-08-24 19:49:36  Rh2k-J1o7-zndZ-cOo8  Unsuccessful         NaN
# 330747  2024-11-01 15:07:21  KaSn-4LHo-m6vC-I4PU  Unsuccessful         NaN
# 1155163 2024-01-15 00:26:48  Rh2k-J1o7-zndZ-cOo8  Unsuccessful         NaN
# 285466  2024-01-12 02:08:11  Rh2k-J1o7-zndZ-cOo8  Unsuccessful         NaN
# 525791  2024-02-19 23:50:27  KaSn-4LHo-m6vC-I4PU  Unsuccessful         NaN
# 864312  2024-09-26 01:02:50  GdEQ-MGb7-LXHa-y6cd  Unsuccessful         NaN
#
#          commerce_nit           commerce_name commerce_status  \
# 1488207     198818316        QuantumLeap Inc.          Active
# 1169407     198818316        QuantumLeap Inc.          Active
# 1333702     198818316        QuantumLeap Inc.          Active
# 839492      445470636      Innovexa Solutions        Inactive
# 295944      919341007  FusionWave Enterprises          Active
# 888732       28960112            Zenith Corp.          Active
# 157830       28960112            Zenith Corp.          Active
# 636435       28960112            Zenith Corp.          Active
# 202690       28960112            Zenith Corp.          Active
# 354401      919341007  FusionWave Enterprises          Active
# 994423      452680670     NexaTech Industries          Active
# 39658       919341007  FusionWave Enterprises          Active
# 972606      919341007  FusionWave Enterprises          Active
# 1394925     445470636      Innovexa Solutions        Inactive
# 363305      198818316        QuantumLeap Inc.          Active
# 330747      445470636      Innovexa Solutions        Inactive
# 1155163     198818316        QuantumLeap Inc.          Active
# 285466      198818316        QuantumLeap Inc.          Active
# 525791      445470636      Innovexa Solutions        Inactive
# 864312      919341007  FusionWave Enterprises          Active
#
#                                 commerce_email
# 1488207            quantumleapinc.@gemaily.net
# 1169407            quantumleapinc.@gemaily.net
# 1333702            quantumleapinc.@gemaily.net
# 839492       innovexasolutions@microfitsof.com
# 295944   fusionwaveenterprises@microfitsof.com
# 888732                 zenithcorp.@gemaily.net
# 157830                 zenithcorp.@gemaily.net
# 636435                 zenithcorp.@gemaily.net
# 202690                 zenithcorp.@gemaily.net
# 354401   fusionwaveenterprises@microfitsof.com
# 994423          nexatechindustries@gemaily.net
# 39658    fusionwaveenterprises@microfitsof.com
# 972606   fusionwaveenterprises@microfitsof.com
# 1394925      innovexasolutions@microfitsof.com
# 363305             quantumleapinc.@gemaily.net
# 330747       innovexasolutions@microfitsof.com
# 1155163            quantumleapinc.@gemaily.net
# 285466             quantumleapinc.@gemaily.net
# 525791       innovexasolutions@microfitsof.com
# 864312   fusionwaveenterprises@microfitsof.com

# %%
apicall_commerce[apicall_commerce["is_related"].isna()]["ask_status"].value_counts()
# Out:
# ask_status
# Unsuccessful    299505
# Name: count, dtype: int64

# %%
# Calculamos el porcentaje de valores ausentes

(apicall_commerce.isna().sum()/apicall_commerce.shape[0])*100
# Out:
# date_api_call       0.000
# commerce_id         0.000
# ask_status          0.000
# is_related         19.967
# commerce_nit        0.000
# commerce_name       0.000
# commerce_status     0.000
# commerce_email      0.000
# dtype: float64

# %% [markdown]
# *Los valores ausentes presentes en la columna "is_related" equivalen a menos de 20% de los registros lo que es un porcentaje bajo. En este caso, como la columna "is_ralated" no es relevante para el calculo de las comisiones no es necesario eliminar o reemplazar estos registros, podemos dejarlos y no va a afectar el analisis.*

# %% [markdown]
# # Verificacion de valores duplicados

# %%
# Verificamos valores duplicados
print(f"filas duplicadas:{apicall_commerce.duplicated().sum()}")
# Out:
# filas duplicadas:2869

# %%
apicall_commerce[apicall_commerce.duplicated()].head(10)
# Out:
#             date_api_call          commerce_id    ask_status  is_related  \
# 22144 2024-03-18 06:26:35  Vj9W-c4Pm-ja0X-fC1C    Successful         0.0
# 38345 2024-05-24 23:50:06  KaSn-4LHo-m6vC-I4PU    Successful         1.0
# 64389 2024-05-23 12:59:42  3VYd-4lzT-mTC3-DQN5  Unsuccessful         NaN
# 64727 2024-06-10 01:52:49  GdEQ-MGb7-LXHa-y6cd    Successful         0.0
# 74988 2024-07-30 14:39:01  3VYd-4lzT-mTC3-DQN5    Successful         1.0
# 87449 2024-05-02 21:18:17  Vj9W-c4Pm-ja0X-fC1C    Successful         1.0
# 89923 2024-11-16 15:52:00  KaSn-4LHo-m6vC-I4PU    Successful         1.0
# 92363 2024-12-27 00:06:10  GdEQ-MGb7-LXHa-y6cd    Successful         1.0
# 96706 2024-01-07 13:57:03  Vj9W-c4Pm-ja0X-fC1C    Successful         1.0
# 99661 2024-08-13 08:24:13  GdEQ-MGb7-LXHa-y6cd    Successful         1.0
#
#        commerce_nit           commerce_name commerce_status  \
# 22144     452680670     NexaTech Industries          Active
# 38345     445470636      Innovexa Solutions        Inactive
# 64389      28960112            Zenith Corp.          Active
# 64727     919341007  FusionWave Enterprises          Active
# 74988      28960112            Zenith Corp.          Active
# 87449     452680670     NexaTech Industries          Active
# 89923     445470636      Innovexa Solutions        Inactive
# 92363     919341007  FusionWave Enterprises          Active
# 96706     452680670     NexaTech Industries          Active
# 99661     919341007  FusionWave Enterprises          Active
#
#                               commerce_email
# 22144         nexatechindustries@gemaily.net
# 38345      innovexasolutions@microfitsof.com
# 64389                zenithcorp.@gemaily.net
# 64727  fusionwaveenterprises@microfitsof.com
# 74988                zenithcorp.@gemaily.net
# 87449         nexatechindustries@gemaily.net
# 89923      innovexasolutions@microfitsof.com
# 92363  fusionwaveenterprises@microfitsof.com
# 96706         nexatechindustries@gemaily.net
# 99661  fusionwaveenterprises@microfitsof.com

# %% [markdown]
# *No tenemos valores duplicados, cada fila tiene valores diferentes para la columan de fechas, no es necesario eliminar filas*
